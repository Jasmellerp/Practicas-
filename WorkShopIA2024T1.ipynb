# %% [markdown]
# <a href="https://colab.research.google.com/github/Jasmellerp/Practicas-/blob/main/WorkShopIA2024T1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Practica de funciones de las listas:

# %%
Personajes = ["Cazador","Mago","Arquero","Caballero","Asesino","Guerrero"]
cofre1 = ["Gemas","Oro"]
cofre2 = ["Arma Poderosa","Oro"]

# %%
Mapa = ["Roca","Pared","Llave2","Nada",cofre1,"Enemigo",cofre2,"enemigo","Enemigo Poderoso","Roca","Oro"]

# %% [markdown]
# Elegir El Personaje:

# %%
Protagonista = []
Mochila = []

# %% [markdown]
# * acabar con los enemigos (el enemigo poderoso solo cuando tengan el arma poderosa)
# * guardar el la mochila elemtos utiles (gemas, oro, armas)
# * No guearde el cofre en la mochila, sino que tomen lo que esta adentro del cofre
# * El juego se acaba cuando el mapa ya no tenga enemigos

# %%
##aquí se eliminaran los enemigos y se obtendran los objetos para ponerlos en la mochila

# %%
#Elegir el personaje
elegirPersonaje = input("Elige tu personaje: Cazador, Mago, Arquero, Caballero, Asesino o Guerrero: ")
if elegirPersonaje in Personajes:
    Protagonista.append(elegirPersonaje)
    print("Bienvenido,", elegirPersonaje)
else:
    print("Favor elegir personaje.")
# Out:
# Elige tu personaje: Cazador, Mago, Arquero, Caballero, Asesino o Guerrero: Caballero
# Bienvenido, Caballero

# %%
def enfrentarEnemigo(Enemigo):
 if "Arma Poderosa" in Mochila and Enemigo == "Enemigo Poderoso":
        print("Derrotaste al", Enemigo)
        Mapa.remove(Enemigo)
 elif Enemigo == "Enemigo":
        print("Derrotaste al", Enemigo)
        Mapa.remove(Enemigo)
 else:
        print("No tienes el arma necesaria para derrotar al", Enemigo)

while "Enemigo"  in Mapa or "Enemigo Poderoso" in Mapa:
 for Lugar in Mapa:
   if Lugar == "Enemigo" or Lugar == "Enemigo Poderoso":
    enfrentarEnemigo(Lugar)
   elif isinstance(Lugar, list):
     print("Has encontrado un cofre, Contiene:", Lugar)
for item in Lugar:
         Mapa[Mapa.index(Lugar)] =  "Vacio"
else:
 print("Continúa explorando.")
print("Tu mochila contiene:", ", ".join(Mochila))
print("Has explorado el mapa completo y derrotaste a todos los enemigos del reino, ¡EXELENTE TRABAJO!")
# Out:
# Streaming output truncated to the last 5000 lines.
# Has encontrado un cofre, Contiene: ['Gemas', 'Oro']
# Has encontrado un cofre, Contiene: ['Arma Poderosa', 'Oro']
# No tienes el arma necesaria para derrotar al Enemigo Poderoso
# Has encontrado un cofre, Contiene: ['Gemas', 'Oro']
# Has encontrado un cofre, Contiene: ['Arma Poderosa', 'Oro']
# No tienes el arma necesaria para derrotar al Enemigo Poderoso
# Has encontrado un cofre, Contiene: ['Gemas', 'Oro']
# Has encontrado un cofre, Contiene: ['Arma Poderosa', 'Oro']
# No tienes el arma necesaria para derrotar al Enemigo Poderoso
# Has encontrado un cofre, Contiene: ['Gemas', 'Oro']
# Has encontrado un cofre, Contiene: ['Arma Poderosa', 'Oro']
# No tienes el arma necesaria para derrotar al Enemigo Poderoso
# Has encontrado un cofre, Contiene: ['Gemas', 'Oro']
# Has encontrado un cofre, Contiene: ['Arma Poderosa', 'Oro']
# No tienes el arma necesaria para derrotar al Enemigo Poderoso
# ...

# %% [markdown]
# Test de Evaluación, Aquí prueva si está correcto

# %%
print(Mapa)
# Out:
# ['Roca', 'Pared', 'Llave2', 'Nada', ['Gemas', 'Oro'], 'Enemigo', ['Arma Poderosa', 'Oro'], 'enemigo', 'Enemigo Poderoso', 'Roca', 'Oro']
